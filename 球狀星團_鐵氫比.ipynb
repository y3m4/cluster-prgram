# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from astropy.coordinates import SkyCoord, Galactocentric
import astropy.units as u
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# 讀取資料
df= pd.read_csv("https://docs.google.com/spreadsheets/d/1rleBpx8sVtwgPmO4xgBEI1ut6k3kTuCu/export?format=csv")


#清除空白資料
df_cleaned = df.dropna(subset=['ra', 'dec', 'pmra', 'pmdec', 'RV', 'parallax'])
ra, dec, pmra, pmdec, RV, parallax = df_cleaned['ra'].values, df_cleaned['dec'].values, df_cleaned['pmra'].values, df_cleaned['pmdec'].values, df_cleaned['RV'].values, df_cleaned['parallax'].values

ra = df_cleaned['ra'].values
dec = df_cleaned['dec'].values
pmra = df_cleaned['pmra'].values
pmdec = df_cleaned['pmdec'].values
RV = df_cleaned['RV'].values
parallax = df_cleaned['parallax'].values
distance = 1000 / parallax
df_cleaned['distance'] = distance

columns_to_clean = ['ra', 'dec', 'pmra', 'pmdec', 'RV', 'parallax', '[Fe/H]']
for col in columns_to_clean:
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')


# 轉換到銀心座標系
coords = SkyCoord(
    ra=df_cleaned['ra'].values * u.degree,
    dec=df_cleaned['dec'].values * u.degree,
    pm_ra_cosdec=df_cleaned['pmra'].values * u.mas / u.yr,
    pm_dec=df_cleaned['pmdec'].values * u.mas / u.yr,
    radial_velocity=df_cleaned['RV'].values * u.km / u.s,
    distance=distance * u.pc,
    frame='icrs'
)

# 提取銀心坐標中的X, Y, Z 位置和速度分量
galactocentric = coords.transform_to(Galactocentric)
X, Y, Z = galactocentric.x.to(u.kpc).value, galactocentric.y.to(u.kpc).value, galactocentric.z.to(u.kpc).value
v_x, v_y, v_z = galactocentric.v_x.to(u.km/u.s).value, galactocentric.v_y.to(u.km/u.s).value, galactocentric.v_z.to(u.km/u.s).value

df_cleaned['X'] = X
df_cleaned['Y'] = Y
df_cleaned['Z'] = Z
df_cleaned['v_x'] = v_x
df_cleaned['v_y'] = v_y
df_cleaned['v_z'] = v_z
df_cleaned['distance_to_gc'] = np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2 + df_cleaned['Z']**2)
max_range = np.max([np.max(np.abs(X)), np.max(np.abs(Y)), np.max(np.abs(Z))])

# 定義位置條件和標籤
conditions = [
    (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2 + df_cleaned['Z']**2) < 3),  #核球
    (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2) < 21) & (np.abs(df_cleaned['Z']) <  1.35),  #銀盤
    (np.abs(df_cleaned['Z']) > 1.35) | (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2) > 21),  #銀暈
]
choices = ['Bulge', 'Disk', 'Halo']


# 新增 'Location' 欄位
df_cleaned['Location'] = np.select(conditions, choices, default='Unknown')

bulge = df_cleaned[(df_cleaned['Location'] == 'Bulge') & df_cleaned['X'].notna()]
disk = df_cleaned[(df_cleaned['Location'] == 'Disk') & df_cleaned['X'].notna()]
halo = df_cleaned[(df_cleaned['Location'] == 'Halo') & df_cleaned['X'].notna()]

# 確保 [Fe/H] 欄位為數值型態
df_cleaned['[Fe/H]'] = pd.to_numeric(df_cleaned['[Fe/H]'], errors='coerce')

# 繪製 3D 散點圖
fig_metallicity = go.Figure()

df_cleaned['hover_text'] = df_cleaned.apply(lambda row:
        f"Name: {row['Name']}<br>" +
        f"[Fe/H]: {row['[Fe/H]']:.2f}<br>" +
        f"Distance to GC: {row['distance_to_gc']:.2f} kpc<br>" +
        f"Location: {row['Location']}", axis=1)

#if feh_min == feh_max or pd.isna(feh_min) or pd.isna(feh_max):
feh_min = df_cleaned['[Fe/H]'].quantile(0.05)
feh_max = df_cleaned['[Fe/H]'].quantile(0.95)

fig_metallicity.add_trace(go.Scatter3d(
    x=df_cleaned['X'],
    y=df_cleaned['Y'],
    z=df_cleaned['Z'],
    mode='markers',
    marker=dict(
        size=6,
        color=df_cleaned['[Fe/H]'],
        colorscale='Viridis_r',
        cmin=feh_min,
        cmax=feh_max,
        colorbar=dict(
            title='[Fe/H]',
            tickvals=np.linspace(feh_min, feh_max, num=6),
            ticktext=[f"{val:.2f}" for val in np.linspace(feh_min, feh_max, num=6)],
            len=0.8,
            thickness=20,
            x=1.1
        ),
        opacity=0.7
    ),
    text=df_cleaned['hover_text'],  # 這裡修正
    hoverinfo='text',
    name='Star Clusters'
))

# 添加地球和銀心
earth_x = -8.122
earth_y = 0
earth_z = 0.027
fig_metallicity.add_trace(go.Scatter3d(
    x=[earth_x],
    y=[earth_y],
    z=[earth_z],
    mode='markers+text',
    marker=dict(
        size=10,
        color='navy',
        opacity=1
    ),
    text=["Earth"],
    textposition="bottom center",
    name="Earth"
))

fig_metallicity.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers+text',
    marker=dict(
        size=10,
        color='crimson',
        opacity=1
    ),
    text=["Galactic Core"],
    textposition="bottom center",
    name="Galactic Core"
))



# 更新布局
fig_metallicity.update_layout(
    title='星團分布 (銀心座標系) - [Fe/H] 色階',
    scene=dict(
        xaxis=dict(range=[-max_range, max_range], title='X (kpc)'),
        yaxis=dict(range=[-max_range, max_range], title='Y (kpc)'),
        zaxis=dict(range=[-max_range, max_range], title='Z (kpc)'),
        aspectmode='cube',
        aspectratio=dict(x=1, y=1, z=1)
    ),
    width=1200,
    height=800,
    margin=dict(r=20, b=10, l=10, t=40),
    showlegend=True
)


fig_metallicity.show()

#繪製 3D 散點圖(以100和400為分界)


# 計算距離銀河中心的距離
df_cleaned['distance_to_gc'] = np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2 + df_cleaned['Z']**2)

small_cluster = df_cleaned[df_cleaned['[Fe/H]'] < -1.5]
large_cluster = df_cleaned[df_cleaned['[Fe/H]'] > -0.5]

# 計算統計數據
small_mean = small_cluster['distance_to_gc'].mean()
large_mean = large_cluster['distance_to_gc'].mean()

small_median = small_cluster['distance_to_gc'].median()
large_median = large_cluster['distance_to_gc'].median()

small_std = small_cluster['distance_to_gc'].std()
large_std = large_cluster['distance_to_gc'].std()



# 統計結果表格
stats_summary = pd.DataFrame({
    'Cluster Type': ['[Fe/H] < -1.5', '[Fe/H] > -0.5'],
    'Mean Distance to GC (kpc)': [small_mean, large_mean],
    'Median Distance to GC (kpc)': [small_median, large_median],
    'Standard Deviation (kpc)': [small_std, large_std]
})


# 計算最大範圍
max_range = np.max([np.max(np.abs(df_cleaned['X'])), np.max(np.abs(df_cleaned['Y'])), np.max(np.abs(df_cleaned['Z']))])

# 建立 3D 圖表
fig = go.Figure()


fig.add_trace(go.Scatter3d(
    x=small_cluster['X'],
    y=small_cluster['Y'],
    z=small_cluster['Z'],
    mode='markers',
    marker=dict(size=6, color='purple', opacity=0.7),
    text=df_cleaned['hover_text'],
    hoverinfo='text',
    name='[Fe/H] < -1.5'
))



fig.add_trace(go.Scatter3d(
    x=large_cluster['X'],
    y=large_cluster['Y'],
    z=large_cluster['Z'],
    mode='markers',
    marker=dict(size=6, color='orange', opacity=0.7),
    text=df_cleaned['hover_text'],
    hoverinfo='text',
    name='[Fe/H] > -0.5'
))

earth_x = -8.122
earth_y = 0
earth_z = 0.027
fig.add_trace(go.Scatter3d(
    x=[earth_x],
    y=[earth_y],
    z=[earth_z],
    mode='markers+text',
    marker=dict(
        size=10,
        color='navy',
        opacity=1
    ),
    text=["Earth"],
    textposition="bottom center",
    name="Earth"
))


fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers+text',
    marker=dict(
        size=10,
        color='crimson',
        opacity=1
    ),
    text=["Galactic Core"],
    textposition="bottom center",
    name="Galactic Core",
    legendgroup='Galactic Core',
    showlegend=True
))

fig.update_layout(
    title='星團分布 (銀心座標系) - 以8與9顆為分界',
    scene=dict(
        xaxis=dict(range=[-max_range, max_range], title='X (kpc)'),
        yaxis=dict(range=[-max_range, max_range], title='Y (kpc)'),
        zaxis=dict(range=[-max_range, max_range], title='Z (kpc)'),
        aspectmode='cube',
        aspectratio=dict(x=1, y=1, z=1)
    ),
    width=1200,
    height=800,
    margin=dict(r=20, b=10, l=10, t=40),
    showlegend=True
)
fig.show()

print("Z Distance Statistics:")
print(stats_summary)
print("\nT-Test Results:")


output_csv_path = '星團分布-FeH色階.csv'
df_cleaned.to_csv(output_csv_path, index=False)

from google.colab import files
files.download('星團分布-FeH色階.csv')

fig.write_html("星團分布-FeH色階.html")
from google.colab import files
files.download("星團分布-FeH色階.html")
# Out:
# <ipython-input-4-bdee635cc8a4>:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:47: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:48: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:49: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:50: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:51: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:52: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:53: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:66: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:73: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-bdee635cc8a4>:78: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7e51135c-b976-4934-b640-9cf7405e724b" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e51135c-b976-4934-b640-9cf7405e724b")) {                    Plotly.newPlot(                        "7e51135c-b976-4934-b640-9cf7405e724b",                        [{"hoverinfo":"text","marker":{"cmax":-0.3190000000000004,"cmin":-2.077,"color":[-1.8,-2.0,-1.76,null,null,-0.8,-1.7,null,-1.6,0.22,-0.62,-0.76,-1.35,-1.26,-1.54,-1.85,-1.37,-1.24,-1.48,-1.16,-1.83,-2.09,-2.06,-1.79,-2.07,-2.29,-1.62,-1.57,-1.67,-2.22,-1.82,-1.86,-1.85,-1.8,-1.29,-0.37,-1.38,-1.67,-1.62,-1.82,-1.2,-1.65,-1.73,-1.04,-1.54,-1.48,-1.44,-1.4,-1.52,-0.7,-1.29,-1.68,-1.32,-2.05,-1.92,-0.59,-0.55,-1.17,-1.72,-2.29,-0.65,-0.7,-1.5,-0.5,-1.06,-0.82,null,-0.6,-1.95,-1.12,-1.39,-2.26,-0.34,-0.53,-1.53,-0.64,-1.37,-1.52,-0.17,-1.8,-0.66,-1.0,-1.83,-1.56,-0.25,-1.44,-0.86,-1.49,-0.42,-1.45,-0.71,-0.99,-1.35,-0.96,-1.64,-1.51,-1.01,-1.59,-1.29,-1.12,-1.6,-1.55,-0.52,-1.94,-1.81,-0.73,-1.32,-1.54,-1.54,-1.68,-2.22,-1.62,-2.12,-1.51,-0.8,-0.1,-0.39,-0.93,-1.65,-1.52,-1.9,-1.3,-1.48,-1.38,-0.1,-0.48,-1.8,-0.35,-0.7,null,-0.25,null,-1.6,-0.28,-0.65,-0.58,-1.87,-1.0,-0.5,-1.2],"colorbar":{"len":0.8,"thickness":20,"ticktext":["-2.08","-1.73","-1.37","-1.02","-0.67","-0.32"],"tickvals":[-2.077,-1.7254,-1.3738000000000001,-1.0222000000000002,-0.6706000000000003,-0.3190000000000004],"title":{"text":"[Fe\u002fH]"},"x":1.1},"colorscale":[[0.0,"#fde725"],[0.1111111111111111,"#b5de2b"],[0.2222222222222222,"#6ece58"],[0.3333333333333333,"#35b779"],[0.4444444444444444,"#1f9e89"],[0.5555555555555556,"#26828e"],[0.6666666666666666,"#31688e"],[0.7777777777777778,"#3e4989"],[0.8888888888888888,"#482878"],[1.0,"#440154"]],"opacity":0.7,"size":6},"mode":"markers","name":"Star Clusters","text":["Name: AM 1     \u003cbr\u003e[Fe\u002fH]: -1.80\u003cbr\u003eDistance to GC: 68.23 kpc\u003cbr\u003eLocation: Halo","Name: AM 4     \u003cbr\u003e[Fe\u002fH]: -2.00\u003cbr\u003eDistance to GC: 9.73 kpc\u003cbr\u003eLocation: Halo","Name: Arp 2    \u003cbr\u003e[Fe\u002fH]: -1.76\u003cbr\u003eDistance to GC: 31.11 kpc\u003cbr\u003eLocation: Halo","Name: Djorg 1  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 2.60 kpc\u003cbr\u003eLocation: Bulge","Name: Djorg 2  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 0.54 kpc\u003cbr\u003eLocation: Bulge","Name: E 3      \u003cbr\u003e[Fe\u002fH]: -0.80\u003cbr\u003eDistance to GC: 8.54 kpc\u003cbr\u003eLocation: Halo","Name: IC 1257  \u003cbr\u003e[Fe\u002fH]: -1.70\u003cbr\u003eDistance to GC: 10.49 kpc\u003cbr\u003eLocation: Halo","Name: IC 1276  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 4.15 kpc\u003cbr\u003eLocation: Disk","Name: IC 4499  \u003cbr\u003e[Fe\u002fH]: -1.60\u003cbr\u003eDistance to GC: 15.42 kpc\u003cbr\u003eLocation: Halo","Name: Liller 1 \u003cbr\u003e[Fe\u002fH]: 0.22\u003cbr\u003eDistance to GC: 3.23 kpc\u003cbr\u003eLocation: Disk","Name: Lynga 7  \u003cbr\u003e[Fe\u002fH]: -0.62\u003cbr\u003eDistance to GC: 4.43 kpc\u003cbr\u003eLocation: Disk","Name: NGC 104  \u003cbr\u003e[Fe\u002fH]: -0.76\u003cbr\u003eDistance to GC: 7.45 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1261 \u003cbr\u003e[Fe\u002fH]: -1.35\u003cbr\u003eDistance to GC: 16.76 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1851 \u003cbr\u003e[Fe\u002fH]: -1.26\u003cbr\u003eDistance to GC: 16.13 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1904 \u003cbr\u003e[Fe\u002fH]: -1.54\u003cbr\u003eDistance to GC: 17.45 kpc\u003cbr\u003eLocation: Halo","Name: NGC 2298 \u003cbr\u003e[Fe\u002fH]: -1.85\u003cbr\u003eDistance to GC: 13.69 kpc\u003cbr\u003eLocation: Halo","Name: NGC 2808 \u003cbr\u003e[Fe\u002fH]: -1.37\u003cbr\u003eDistance to G ...
# <ipython-input-4-bdee635cc8a4>:173: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c1bc9c5-eb7c-43d0-aace-b57dd6f2dde1" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1bc9c5-eb7c-43d0-aace-b57dd6f2dde1")) {                    Plotly.newPlot(                        "5c1bc9c5-eb7c-43d0-aace-b57dd6f2dde1",                        [{"hoverinfo":"text","marker":{"color":"purple","opacity":0.7,"size":6},"mode":"markers","name":"[Fe\u002fH] \u003c -1.5","text":["Name: AM 1     \u003cbr\u003e[Fe\u002fH]: -1.80\u003cbr\u003eDistance to GC: 68.23 kpc\u003cbr\u003eLocation: Halo","Name: AM 4     \u003cbr\u003e[Fe\u002fH]: -2.00\u003cbr\u003eDistance to GC: 9.73 kpc\u003cbr\u003eLocation: Halo","Name: Arp 2    \u003cbr\u003e[Fe\u002fH]: -1.76\u003cbr\u003eDistance to GC: 31.11 kpc\u003cbr\u003eLocation: Halo","Name: Djorg 1  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 2.60 kpc\u003cbr\u003eLocation: Bulge","Name: Djorg 2  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 0.54 kpc\u003cbr\u003eLocation: Bulge","Name: E 3      \u003cbr\u003e[Fe\u002fH]: -0.80\u003cbr\u003eDistance to GC: 8.54 kpc\u003cbr\u003eLocation: Halo","Name: IC 1257  \u003cbr\u003e[Fe\u002fH]: -1.70\u003cbr\u003eDistance to GC: 10.49 kpc\u003cbr\u003eLocation: Halo","Name: IC 1276  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 4.15 kpc\u003cbr\u003eLocation: Disk","Name: IC 4499  \u003cbr\u003e[Fe\u002fH]: -1.60\u003cbr\u003eDistance to GC: 15.42 kpc\u003cbr\u003eLocation: Halo","Name: Liller 1 \u003cbr\u003e[Fe\u002fH]: 0.22\u003cbr\u003eDistance to GC: 3.23 kpc\u003cbr\u003eLocation: Disk","Name: Lynga 7  \u003cbr\u003e[Fe\u002fH]: -0.62\u003cbr\u003eDistance to GC: 4.43 kpc\u003cbr\u003eLocation: Disk","Name: NGC 104  \u003cbr\u003e[Fe\u002fH]: -0.76\u003cbr\u003eDistance to GC: 7.45 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1261 \u003cbr\u003e[Fe\u002fH]: -1.35\u003cbr\u003eDistance to GC: 16.76 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1851 \u003cbr\u003e[Fe\u002fH]: -1.26\u003cbr\u003eDistance to GC: 16.13 kpc\u003cbr\u003eLocation: Halo","Name: NGC 1904 \u003cbr\u003e[Fe\u002fH]: -1.54\u003cbr\u003eDistance to GC: 17.45 kpc\u003cbr\u003eLocation: Halo","Name: NGC 2298 \u003cbr\u003e[Fe\u002fH]: -1.85\u003cbr\u003eDistance to GC: 13.69 kpc\u003cbr\u003eLocation: Halo","Name: NGC 2808 \u003cbr\u003e[Fe\u002fH]: -1.37\u003cbr\u003eDistance to GC: 10.75 kpc\u003cbr\u003eLocation: Halo","Name: NGC 288  \u003cbr\u003e[Fe\u002fH]: -1.24\u003cbr\u003eDistance to GC: 10.83 kpc\u003cbr\u003eLocation: Halo","Name: NGC 3201 \u003cbr\u003e[Fe\u002fH]: -1.48\u003cbr\u003eDistance to GC: 8.78 kpc\u003cbr\u003eLocation: Disk","Name: NGC 362  \u003cbr\u003e[Fe\u002fH]: -1.16\u003cbr\u003eDistance to GC: 9.56 kpc\u003cbr\u003eLocation: Halo","Name: NGC 4147 \u003cbr\u003e[Fe\u002fH]: -1.83\u003cbr\u003eDistance to GC: 35.94 kpc\u003cbr\u003eLocation: Halo","Name: NGC 4372 \u003cbr\u003e[Fe\u002fH]: -2.09\u003cbr\u003eDistance to GC: 7.11 kpc\u003cbr\u003eLocation: Disk","Name: NGC 4590 \u003cbr\u003e[Fe\u002fH]: -2.06\u003cbr\u003eDistance to GC: 9.32 kpc\u003cbr\u003eLocation: Halo","Name: NGC 4833 \u003cbr\u003e[Fe\u002fH]: -1.79\u003cbr\u003eDistance to GC: 6.99 kpc\u003cbr\u003eLocation: Disk","Name: NGC 5024 \u003cbr\u003e[Fe\u002fH]: -2.07\u003cbr\u003eDistance to GC: 15.82 kpc\u003cbr\u003eLocation: Halo","Name: NGC 5053 \u003cbr\u003e[Fe\u002fH]: -2.29\u003cbr\u003eDistance to GC: 20.23 kpc\u003cbr\u003eLocation: Halo","Name: NGC 5139 \u003cbr\u003e[Fe\u002fH]: -1.62\u003cbr\u003eDistance to GC: 6.44 kpc\u003cbr\u003eLocation: Halo","Name: NGC 5272 \u003cbr\u003e[Fe\u002fH]: -1.57\u003cbr\u003eDistance to GC: 11.28 kpc\u003cbr\u003eLocation: Halo","Name: NGC 5286 \u003cbr\u003e[Fe\u002fH]: -1.67 ...
# Z Distance Statistics:
#     Cluster Type  Mean Distance to GC (kpc)  Median Distance to GC (kpc)  \
# 0  [Fe/H] < -1.5                  11.555658                     9.080522
# 1  [Fe/H] > -0.5                   3.785916                     2.355914
#
#    Standard Deviation (kpc)
# 0                 11.194320
# 1                  3.793122
#
# T-Test Results:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 確保 '[Fe/H]' 是數值
df_cleaned['[Fe/H]'] = pd.to_numeric(df_cleaned['[Fe/H]'], errors='coerce')

# 過濾 NaN
df_cleaned = df_cleaned.dropna(subset=['X', 'Y', 'Z', '[Fe/H]'])

# 計算色階範圍
feh_min = df_cleaned['[Fe/H]'].quantile(0.05)
feh_max = df_cleaned['[Fe/H]'].quantile(0.95)

# 設定銀河中心和地球的位置
earth_x, earth_y, earth_z = -8.122, 0, 0.027
galactic_core_x, galactic_core_y, galactic_core_z = 0, 0, 0  # 銀河中心

# 設定圖表大小
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# 計算 XY 和 XZ 平面的範圍，確保 0 在範圍內
x_min, x_max = min(df_cleaned['X'].min(), 0), df_cleaned['X'].max()
y_min, y_max = min(df_cleaned['Y'].min(), 0), df_cleaned['Y'].max()
z_min, z_max = min(df_cleaned['Z'].min(), 0), df_cleaned['Z'].max()

# 計算 XY 和 XZ 平面的比例
xy_aspect = (x_max - x_min) / (y_max - y_min) if (y_max - y_min) != 0 else 1
xz_aspect = (x_max - x_min) / (z_max - z_min) if (z_max - z_min) != 0 else 1

# 反轉色階
cmap_reversed = plt.cm.get_cmap('viridis_r')  # 使用 Viridis 的反轉版本

# ======= XY 平面投影 (X vs Y) =======
sc1 = axes[0].scatter(df_cleaned['X'], df_cleaned['Y'], c=df_cleaned['[Fe/H]'], cmap=cmap_reversed, vmin=feh_min, vmax=feh_max, alpha=0.7)
axes[0].scatter(earth_x, earth_y, color='blue', s=100, label='Earth', edgecolors='black')
axes[0].scatter(galactic_core_x, galactic_core_y, color='red', s=100, label='Galactic Core', edgecolors='black')  # 銀河中心
axes[0].set_xlabel('X (kpc)')
axes[0].set_ylabel('Y (kpc)')
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)
axes[0].set_aspect(aspect=xy_aspect)  # 確保XY比例相同
axes[0].set_title(' ')
axes[0].legend()
plt.colorbar(sc1, ax=axes[0], label='[Fe/H]')

# ======= XZ 平面投影 (X vs Z) =======
sc2 = axes[1].scatter(df_cleaned['X'], df_cleaned['Z'], c=df_cleaned['[Fe/H]'], cmap=cmap_reversed, vmin=feh_min, vmax=feh_max, alpha=0.7)
axes[1].scatter(earth_x, earth_z, color='blue', s=100, label='Earth', edgecolors='black')
axes[1].scatter(galactic_core_x, galactic_core_z, color='red', s=100, label='Galactic Core', edgecolors='black')  # 銀河中心
axes[1].set_xlabel('X (kpc)')
axes[1].set_ylabel('Z (kpc)')
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(z_min, z_max)
axes[1].set_aspect(aspect=xz_aspect)  # 確保XZ比例相同
axes[1].set_title(' ')
axes[1].legend()
plt.colorbar(sc2, ax=axes[1], label='[Fe/H]')

# 顯示圖表
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-6395f28568a0>:32: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.

# %%
# 設定分段條件
small_cluster = df_cleaned[df_cleaned['[Fe/H]'] < -1.5]
large_cluster = df_cleaned[df_cleaned['[Fe/H]'] > -0.5]

# 設定圖表大小
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ======= XY 平面投影 (X vs Y) =======
axes[0].scatter(small_cluster['X'], small_cluster['Y'], color='purple', label='[Fe/H] < -1.5', alpha=0.7)
axes[0].scatter(large_cluster['X'], large_cluster['Y'], color='orange', label='[Fe/H] > -0.5', alpha=0.7)
axes[0].scatter(earth_x, earth_y, color='blue', s=100, label='Earth', edgecolors='black')
axes[0].scatter(galactic_core_x, galactic_core_y, color='red', s=100, label='Galactic Core', edgecolors='black')
axes[0].set_xlabel('X (kpc)')
axes[0].set_ylabel('Y (kpc)')
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)
axes[0].set_aspect(aspect=xy_aspect)
axes[0].set_title(' ')
axes[0].legend()

# ======= XZ 平面投影 (X vs Z) =======
axes[1].scatter(small_cluster['X'], small_cluster['Z'], color='purple', label='[Fe/H] < -1.5', alpha=0.7)
axes[1].scatter(large_cluster['X'], large_cluster['Z'], color='orange', label='[Fe/H] > -0.5', alpha=0.7)
axes[1].scatter(earth_x, earth_z, color='blue', s=100, label='Earth', edgecolors='black')
axes[1].scatter(galactic_core_x, galactic_core_z, color='red', s=100, label='Galactic Core', edgecolors='black')
axes[1].set_xlabel('X (kpc)')
axes[1].set_ylabel('Z (kpc)')
axes[1].set_xlim(x_min, x_max)
axes[1].set_ylim(z_min, z_max)
axes[1].set_aspect(aspect=xz_aspect)
axes[1].set_title(' ')
axes[1].legend()

# 顯示圖表
plt.tight_layout()
plt.show()
