# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from astropy.coordinates import SkyCoord, Galactocentric
import astropy.units as u

# 讀取資料
df= pd.read_csv("https://docs.google.com/spreadsheets/d/1rleBpx8sVtwgPmO4xgBEI1ut6k3kTuCu/export?format=csv")


#清除空白資料
df_cleaned = df.dropna(subset=['ra', 'dec', 'pmra', 'pmdec', 'RV', 'parallax'])
ra, dec, pmra, pmdec, RV, parallax = df_cleaned['ra'].values, df_cleaned['dec'].values, df_cleaned['pmra'].values, df_cleaned['pmdec'].values, df_cleaned['RV'].values, df_cleaned['parallax'].values

ra = df_cleaned['ra'].values
dec = df_cleaned['dec'].values
pmra = df_cleaned['pmra'].values
pmdec = df_cleaned['pmdec'].values
RV = df_cleaned['RV'].values
parallax = df_cleaned['parallax'].values


distance = 1000 / parallax

columns_to_clean = ['ra', 'dec', 'pmra', 'pmdec', 'RV', 'parallax', '[Fe/H]']
for col in columns_to_clean:
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')


# 轉換到銀心座標系
coords = SkyCoord(
    ra=df_cleaned['ra'].values * u.degree,
    dec=df_cleaned['dec'].values * u.degree,
    pm_ra_cosdec=df_cleaned['pmra'].values * u.mas / u.yr,
    pm_dec=df_cleaned['pmdec'].values * u.mas / u.yr,
    radial_velocity=df_cleaned['RV'].values * u.km / u.s,
    distance=distance * u.pc,
    frame='icrs'
)




# 提取銀心坐標中的X, Y, Z 位置和速度分量
galactocentric = coords.transform_to(Galactocentric)
X, Y, Z = galactocentric.x.to(u.kpc).value, galactocentric.y.to(u.kpc).value, galactocentric.z.to(u.kpc).value
v_x, v_y, v_z = galactocentric.v_x.to(u.km/u.s).value, galactocentric.v_y.to(u.km/u.s).value, galactocentric.v_z.to(u.km/u.s).value

df_cleaned['X'] = X
df_cleaned['Y'] = Y
df_cleaned['Z'] = Z
df_cleaned['v_x'] = v_x
df_cleaned['v_y'] = v_y
df_cleaned['v_z'] = v_z
df_cleaned['distance_to_gc'] = np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2 + df_cleaned['Z']**2)

max_range = np.max([np.max(np.abs(X)), np.max(np.abs(Y)), np.max(np.abs(Z))])


# 計算內積
R = np.array([X, Y, Z])
V = np.array([v_x, v_y, v_z])


df_cleaned['r_dot_v'] = np.sum(R * V, axis=0)
r_dot_v= df_cleaned['r_dot_v'].values

norm_R = np.linalg.norm(R)
norm_V = np.linalg.norm(V)

# 計算夾角（單位：弧度）
cos_theta = r_dot_v / (norm_R * norm_V)
theta_rad = np.arccos(np.clip(cos_theta, -1.0, 1.0))

df_cleaned['theta_deg'] = np.degrees(theta_rad)

target_angle = 90.0
tolerance = 1.0


lower = target_angle - tolerance
upper = target_angle + tolerance  #

# 篩選夾角在範圍內的數據
df_cleaned['Is_Orbiting'] = (df_cleaned['theta_deg'] >= lower) & (df_cleaned['theta_deg'] <= upper)


# 定義位置條件和標籤
conditions = [
    (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2 + df_cleaned['Z']**2) < 1.5),  #核球
    (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2) < 21) & (np.abs(df_cleaned['Z']) <  1.35),  #銀盤
    (np.abs(df_cleaned['Z']) > 1.5) | (np.sqrt(df_cleaned['X']**2 + df_cleaned['Y']**2) > 21),  #銀暈

]
choices = ['Bulge', 'Disk', 'Halo']

# 新增 'Location' 欄位
df_cleaned['Location'] = np.select(conditions, choices, default='Unknown')

bulge = df_cleaned[(df_cleaned['Location'] == 'Bulge') & df_cleaned['X'].notna()]
disk = df_cleaned[(df_cleaned['Location'] == 'Disk') & df_cleaned['X'].notna()]
halo = df_cleaned[(df_cleaned['Location'] == 'Halo') & df_cleaned['X'].notna()]

# 體積計算
r_halo = 38.51
r_bulge = 1.5
r_disk = 21
h_disk = 1.35
V_bulge = (4 / 3) * np.pi * (r_bulge**3)
V_disk = np.pi * (r_disk**2) * h_disk
V_halo = (4 / 3) * np.pi * (r_halo**3) - V_bulge - V_disk

print("各位置的體積（每 kpc³）：")
print(f"核球（Bulge）：{V_bulge:.4f}")
print(f"銀盤（Disk）：{V_disk:.4f}")
print(f"銀暈（Halo）：{V_halo:.4f}")

# 星團數量
location_counts = df_cleaned['Location'].value_counts()

print("數量：")
for location, count in location_counts.items():
    print(f"{location}: {count} 個星團")


# 密度計算
density_bulge = location_counts.get('Bulge', 0) / V_bulge
density_disk = location_counts.get('Disk', 0) / V_disk
density_halo = location_counts.get('Halo', 0) / V_halo


# 結果列印
print("各位置的星團密度（每 kpc³）：")
print(f"核球（Bulge）：{density_bulge:.4f}")
print(f"銀盤（Disk）：{density_disk:.4f}")
print(f"銀暈（Halo）：{density_halo:.10f}")

df_cleaned['hover_text'] = df_cleaned.apply(lambda row:
        f"Name: {row['Name']}<br>" +
        f"[Fe/H]: {row['[Fe/H]']}<br>" +
        f"Distance to GC: {row['distance_to_gc']:.2f} kpc<br>" +
        f"Location: {row['Location']}", axis=1)

bulge = df_cleaned[df_cleaned['Location'] == 'Bulge'].copy()
disk = df_cleaned[df_cleaned['Location'] == 'Disk'].copy()
halo = df_cleaned[df_cleaned['Location'] == 'Halo'].copy()

# 繪製位置的 3D 圖
fig_location = go.Figure()
fig_location.add_trace(go.Scatter3d(
    x=bulge['X'],
    y=bulge['Y'],
    z=bulge['Z'],
    mode='markers',
    marker=dict(size=6, color='deepskyblue', opacity=0.5),
    text=bulge['hover_text'],
    hoverinfo='text',
    name='Bulge'
))


fig_location.add_trace(go.Scatter3d(
    x=disk['X'],
    y=disk['Y'],
    z=disk['Z'],
    mode='markers',
    marker=dict(size=6, color='orange', opacity=0.5),
    text=disk['hover_text'],  # 這裡修正
    hoverinfo='text',
    name='Disk'
))


fig_location.add_trace(go.Scatter3d(
    x=halo['X'],
    y=halo['Y'],
    z=halo['Z'],
    mode='markers',
    marker=dict(size=6, color='purple', opacity=0.5),
    text=halo['hover_text'],  # 這裡修正
    hoverinfo='text',
    name='Halo'
))


earth_x = -8.122
earth_y = 0
earth_z = 0.027
fig_location.add_trace(go.Scatter3d(
    x=[earth_x],
    y=[earth_y],
    z=[earth_z],
    mode='markers+text',
    marker=dict(
        size=10,
        color='navy',
        opacity=1
    ),
    text=["Earth"],
    textposition="bottom center",
    name="Earth"
))


fig_location.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers+text',
    marker=dict(
        size=10,
        color='crimson',
        opacity=1
    ),
    text=["Galactic Core"],
    textposition="bottom center",
    name="Galactic Core",
    legendgroup='Galactic Core',
    showlegend=True
))


fig_location.update_layout(title=' 球狀星團分布 (銀心座標系)', scene=dict(
        xaxis=dict(range=[-max_range, max_range], title='X (kpc)'),
        yaxis=dict(range=[-max_range, max_range], title='Y (kpc)'),
        zaxis=dict(range=[-max_range, max_range], title='Z (kpc)'),
        aspectmode='manual',
        aspectratio=dict(x=1, y=1, z=1)
    ),
    width=1920,
    height=1080,
    margin=dict(r=20, b=10, l=10, t=40),
    showlegend=True,
    legend=dict(
        x=0.7,
        y=0.9,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="rgba(255, 255, 255, 0.8)",
        bordercolor="lightgray",
        borderwidth=1
    )
)

fig_location.show()

output_csv_path = '球狀星團分布.csv'
df_cleaned.to_csv(output_csv_path, index=False)

from google.colab import files
files.download('球狀星團分布.csv')

fig_location.write_html("球狀星團分布.html")
from google.colab import files
files.download("球狀星團分布.html")
# Out:
# <ipython-input-4-06f5959f2884>:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:49: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:50: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:51: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:52: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:53: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:54: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:55: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:65: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:75: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:85: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:98: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-4-06f5959f2884>:138: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 各位置的體積（每 kpc³）：
# 核球（Bulge）：14.1372
# 銀盤（Disk）：1870.3472
# 銀暈（Halo）：237341.9489
# 數量：
# Halo: 72 個星團
# Disk: 56 個星團
# Bulge: 9 個星團
# Unknown: 3 個星團
# 各位置的星團密度（每 kpc³）：
# 核球（Bulge）：0.6366
# 銀盤（Disk）：0.0299
# 銀暈（Halo）：0.0003033598
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a2270eb-06d2-43ff-b928-1d1ccc45cef9" class="plotly-graph-div" style="height:1080px; width:1920px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a2270eb-06d2-43ff-b928-1d1ccc45cef9")) {                    Plotly.newPlot(                        "3a2270eb-06d2-43ff-b928-1d1ccc45cef9",                        [{"hoverinfo":"text","marker":{"color":"deepskyblue","opacity":0.5,"size":6},"mode":"markers","name":"Bulge","text":["Name: Djorg 2  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 0.54 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6293 \u003cbr\u003e[Fe\u002fH]: -1.92\u003cbr\u003eDistance to GC: 1.17 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6316 \u003cbr\u003e[Fe\u002fH]: -0.55\u003cbr\u003eDistance to GC: 1.20 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6522 \u003cbr\u003e[Fe\u002fH]: -1.52\u003cbr\u003eDistance to GC: 0.58 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6528 \u003cbr\u003e[Fe\u002fH]: -0.17\u003cbr\u003eDistance to GC: 0.62 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6569 \u003cbr\u003e[Fe\u002fH]: -0.86\u003cbr\u003eDistance to GC: 1.28 kpc\u003cbr\u003eLocation: Bulge","Name: NGC 6624 \u003cbr\u003e[Fe\u002fH]: -0.42\u003cbr\u003eDistance to GC: 1.23 kpc\u003cbr\u003eLocation: Bulge","Name: Terzan 10\u003cbr\u003e[Fe\u002fH]: -0.7\u003cbr\u003eDistance to GC: 1.38 kpc\u003cbr\u003eLocation: Bulge","Name: Terzan 5 \u003cbr\u003e[Fe\u002fH]: -0.28\u003cbr\u003eDistance to GC: 1.34 kpc\u003cbr\u003eLocation: Bulge"],"x":[0.056424943739799345,-0.3254463968921364,0.6743869108082062,-0.14344725342961648,-0.14628508207730193,0.7429657047646515,-0.5146744085799883,-1.250169558744079,-1.243099647615546],"y":[0.3948215987675012,-0.32381904477092666,-0.4338610361500478,0.14272767458557017,0.15853091280286571,0.0745193447392785,0.3706246381466026,0.531298353167278,0.45817032122779483],"z":[-0.3588804556289742,1.0740959909533332,0.887101804874902,-0.5473107990422198,-0.5819141490236145,-1.040656495492706,-1.0577349235469644,-0.22098539354934582,0.20410849760161506],"type":"scatter3d"},{"hoverinfo":"text","marker":{"color":"orange","opacity":0.5,"size":6},"mode":"markers","name":"Disk","text":["Name: Djorg 1  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 2.60 kpc\u003cbr\u003eLocation: Disk","Name: IC 1276  \u003cbr\u003e[Fe\u002fH]: nan\u003cbr\u003eDistance to GC: 4.15 kpc\u003cbr\u003eLocation: Disk","Name: Liller 1 \u003cbr\u003e[Fe\u002fH]: 0.22\u003cbr\u003eDistance to GC: 3.23 kpc\u003cbr\u003eLocation: Disk","Name: Lynga 7  \u003cbr\u003e[Fe\u002fH]: -0.62\u003cbr\u003eDistance to GC: 4.43 kpc\u003cbr\u003eLocation: Disk","Name: NGC 3201 \u003cbr\u003e[Fe\u002fH]: -1.48\u003cbr\u003eDistance to GC: 8.78 kpc\u003cbr\u003eLocation: Disk","Name: NGC 4372 \u003cbr\u003e[Fe\u002fH]: -2.09\u003cbr\u003eDistance to GC: 7.11 kpc\u003cbr\u003eLocation: Disk","Name: NGC 4833 \u003cbr\u003e[Fe\u002fH]: -1.79\u003cbr\u003eDistance to GC: 6.99 kpc\u003cbr\u003eLocation: Disk","Name: NGC 5927 \u003cbr\u003e[Fe\u002fH]: -0.37\u003cbr\u003eDistance to GC: 4.64 kpc\u003cbr\u003eLocation: Disk","Name: NGC 5946 \u003cbr\u003e[Fe\u002fH]: -1.38\u003cbr\u003eDistance to GC: 4.86 kpc\u003cbr\u003eLocation: Disk","Name: NGC 6121 \u003cbr\u003e[Fe\u002fH]: -1.2\u003cbr\u003eDistance to GC: 6.44 kpc\u003cbr\u003eLocation: Disk","Name: NGC 6139 \u003cbr\u003e[Fe\u002fH]: -1.65\u003cbr\u003eDistance to GC: 2.91 kpc\u003cbr\u003eLocation: Disk","Name: NGC 6256 \u003cbr\u003e[Fe\u002fH]: -0.7\u003cbr\u003eDistance to GC: 2.50 kpc\u003cbr\u003eLocation: Disk","Name: NGC 6266 \u003cbr\u003e[Fe\u002fH]: -1.29\u003cbr\u003eDistance to GC: 2.94 kpc\u003cbr\u003eLocation: Disk","Name: NGC 6273 \u003cbr\u003e[Fe\u002fH]: -1.68\u003cbr\u003eDistance to GC: 1.69 kp ...
